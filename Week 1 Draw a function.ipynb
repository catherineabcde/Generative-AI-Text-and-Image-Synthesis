# %% [markdown]
# <a href="https://colab.research.google.com/github/catherineabcde/Generative-AI-Text-and-Image-Synthesis/blob/main/Week%201%20Draw%20a%20function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **<font color="#0000FF">畫一個函數圖形（Week 1 作業）</font>**
#
# 以下圖形依據資料來源稱為等角螺線，是阿基米德的等速螺線的更進化版！
# 在極座標 $(r, \theta)$ 中，此曲線可以寫為：
#
# $$r = a*e^{b\theta}$$
#
#
#
# > 📂 資料來源：[等角螺線](https://zh.wikipedia.org/zh-tw/%E7%AD%89%E8%A7%92%E8%9E%BA%E7%BA%BF)
#
# ###  **<font color="#0000FF">選擇此函數圖形的原因</font>**
#
# 在選擇圖形的過程看到許多漂亮的數學函數，但是很多都是為了造就那個形狀而沒有特別物理意義的圖形。當我認識到這個函數圖形時，除了等角速度的特性還有背後的歷史故事都很有趣，所以最後就決定選擇它了。

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a = 0.1
b = 0.05
turns = 200
n = 10000

theta = np.linspace(0.0, 2*turns*np.pi, n)
r = a*np.exp(b*theta)

x = r*np.cos(theta)
y = r*np.sin(theta)

plt.plot(x, y, color="#998dff", marker="*", linewidth=4) # color: 控制顏色; marker: 控制點的形狀; linewidth: 控制圖形的線條寬度

# %% [markdown]
# ### **<font color="#0000FF">變數說明</font>**
#
# *   `a`: 螺線的起始半徑，控制羅線整體圖形的大小。
# *   `b`: 決定半徑隨角度增長的速度，與等角角度有直接關係，可以說是開口角度的控制器，越大越緊密，越小越開放。
# *   `turns`: 螺線走的範圍（螺線旋轉圈數）。
# *   `n`: 選取樣本數量（同老師的上課範例），如果 `turns` 或 `n` 數量減少圖形會變成鋸齒狀。
# *   `theta`: 希望圖形涵蓋的角度範圍，如果縮小設定範圍，所呈現的圈數就會變比較少圈或是無法建構完整圓形。
#
# 經過不同的組合測試，覺得這樣調整的數值所呈現的圖形最和諧，因此選擇這組數字。
